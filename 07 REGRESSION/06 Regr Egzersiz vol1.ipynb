# %% [markdown]
# # **REGRESSION Vol1**

# %% [markdown]
# ## Import & Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_boston

# %%
# help(datasets)

# %%
data = load_boston()

# %%
type(data)
# Out:
# sklearn.utils._bunch.Bunch

# %%
dir(data)
# Out:
# ['DESCR', 'data', 'data_module', 'feature_names', 'filename', 'target']

# %%
print(data.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
type(data.data)
# Out:
# numpy.ndarray

# %%
data.data.shape
# Out:
# (506, 13)

# %%
data.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
data.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
df = pd.DataFrame(data=data.data, columns=data.feature_names)

df["PRICE"] = data.target

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  PRICE
# 0       15.3  396.90   4.98   24.0
# ...

# %% [markdown]
# ___
# ___

# %% [markdown]
# ## Veri Kontrol

# %%
df.count()
# Out:
# CRIM       506
# ZN         506
# INDUS      506
# CHAS       506
# NOX        506
# RM         506
# AGE        506
# DIS        506
# RAD        506
# TAX        506
# PTRATIO    506
# B          506
# LSTAT      506
# PRICE      506
# dtype: int64

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# PRICE      0
# dtype: int64

# %%
df.isnull().any()
# Out:
# CRIM       False
# ZN         False
# INDUS      False
# CHAS       False
# NOX        False
# RM         False
# AGE        False
# DIS        False
# RAD        False
# TAX        False
# PTRATIO    False
# B          False
# LSTAT      False
# PRICE      False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  PRICE    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %% [markdown]
# ___
# ___

# %% [markdown]
# ## Veriyi Görselleştirme

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["PRICE"], bins=50, ec="black", color="#125FD7", kde=True)
plt.xlabel("Ev Fiyatları (1000 $)", size=12)
plt.ylabel("Ev Sayısı", size=12);
plt.grid()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["RAD"], bins=24, ec="black", color="#125FD7")
plt.xlabel("Otoyola Erişim", size=12)
plt.ylabel("Ev Sayısı", size=12);
plt.grid()

# %%
df["RAD"].value_counts()
# Out:
# 24.0    132
# 5.0     115
# 4.0     110
# 3.0      38
# 6.0      26
# 2.0      24
# 8.0      24
# 1.0      20
# 7.0      17
# Name: RAD, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["RM"],bins=7, ec="black", color="#125FD7", kde=True)
plt.xlabel("Oda Sayısı", size=12)
plt.ylabel("Ev Sayısı", size=12)
plt.xlim(3,9)
plt.grid()

# %%
df["RM"].mean()
# Out:
# 6.284634387351779

# %% [markdown]
# ___
# ___

# %% [markdown]
# ## İstatistiksel Veriler
# (Descriptive Statistics)

# %%
df["PRICE"].max()
# Out:
# 50.0

# %%
df["LSTAT"].mean()
# Out:
# 12.653063241106722

# %%
df.min()
# Out:
# CRIM         0.00632
# ZN           0.00000
# INDUS        0.46000
# CHAS         0.00000
# NOX          0.38500
# RM           3.56100
# AGE          2.90000
# DIS          1.12960
# RAD          1.00000
# TAX        187.00000
# PTRATIO     12.60000
# B            0.32000
# LSTAT        1.73000
# PRICE        5.00000
# dtype: float64

# %%
df.max()
# Out:
# CRIM        88.9762
# ZN         100.0000
# INDUS       27.7400
# CHAS         1.0000
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# PRICE       50.0000
# dtype: float64

# %%
df.mean()
# Out:
# CRIM         3.613524
# ZN          11.363636
# INDUS       11.136779
# CHAS         0.069170
# NOX          0.554695
# RM           6.284634
# AGE         68.574901
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.653063
# PRICE       22.532806
# dtype: float64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ___
# ___

# %% [markdown]
# ## Korelasyon

# %%
df["PRICE"].corr(df["CRIM"])
# Out:
# -0.3883046085868113

# %%
df["PRICE"].corr(df["NOX"])
# Out:
# -0.42732077237328264

# %%
df["PRICE"].corr(df["RM"])
# Out:
# 0.6953599470715396

# %%
# Pearson korelasyon katsayısını verir
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# ___
# ___

# %% [markdown]
# ## Daha Fazla Görselleştirme

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.corr(), annot=True, annot_kws={"size": 14})
sns.set_style('white')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
age_price = round(df["AGE"].corr(df["PRICE"]), 3)

plt.figure(figsize=(12,8))
plt.scatter(x=df["PRICE"], y=df["AGE"],
    alpha=0.4, s=50, color="purple")
plt.title(f"Bina Yaş VS Fiyatı (Korelasyon = {age_price})", size=20)
plt.xlabel("Bina Fiyatı (1000 $)", size=14)
plt.ylabel("Bina Yaşı", size=14)
# Out:
# Text(0, 0.5, 'Bina Yaşı')

# %%
room_price = round(df["RM"].corr(df["PRICE"]), 3)

plt.figure(figsize=(12,8))
plt.scatter(x=df["PRICE"], y=df["RM"],
    alpha=0.4, s=100, color="purple")
plt.title(f"Oda Sayısı VS Fiyatı (Korelasyon = {room_price}", size=20)
plt.xlabel("Bina Fiyatı (1000 $)", size=14)
plt.ylabel("Oda Sayısı", size=14)
# Out:
# Text(0, 0.5, 'Oda Sayısı')

# %%
sns.set()
sns.set_context("talk") # Görseli değiştirmek için kullanılır
sns.set_style('whitegrid')
sns.jointplot(x=df['PRICE'], y=df['RM'], height=8, color='purple', joint_kws={'alpha':0.5})

# %%
sns.set_style("darkgrid")
sns.jointplot(x=df['PRICE'], y=df['RM'], kind="reg", height=8, color='purple')
plt.show()

# %%
sns.set_style("darkgrid")
sns.jointplot(x=df['PRICE'], y=df['RM'], kind="hex", height=8, color='purple')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.lmplot(x="PRICE", y="RM", data=df, height=10)
plt.title(f"Oda Sayısı VS Fiyatı (Korelasyon = {room_price})", size=20)
plt.xlabel("Bina Fiyatı (1000 $)", size=14)
plt.ylabel("Oda Sayısı", size=14);

# %%
# %%time

sns.pairplot(df)
plt.show()
# Out:
# CPU times: total: 27.6 s
# Wall time: 27.6 s

# %%
# %%time

sns.pairplot(df, kind='reg', plot_kws={'line_kws':{'color': 'red'}})
plt.show()
# Out:
# CPU times: total: 45.3 s
# Wall time: 45.4 s

# %% [markdown]
# ___
# ___

# %% [markdown]
# # **https://youtu.be/_f0I5jzI1xY?t=348**
